# %%
import pandas as pd

# %%
# df1 = pd.read_csv(u'c:\\Users\\dev\\Documents\\Visual Studio 2012\\Projects\\OsEngine-master\\OsEngine-master\\project\\OsEngine\\bin\\Debug\\Data\\Set_set2\\АЛРОСА ао\\Sec1\\АЛРОСА ао.txt', encoding='cp1251')
df1 = pd.read_csv('alrs_m30.csv', sep=',')

# %%
df2 = pd.read_csv('alrs_s1.csv', sep=',', header = 0)

# %%
# df2 = pd.read_csv(u'c:\\Users\\dev\\Documents\\Visual Studio 2012\\Projects\\OsEngine-master\\OsEngine-master\\project\\OsEngine\\bin\\Debug\\Data\\Set_set2\\АЛРОСА ао\\Sec1\\АЛРОСА ао.txt', encoding='cp1251')
#df2 = pd.read_csv('c:\\Users\\dev\\alrs_s1.csv')
df2 = pd.read_csv('c:\\Users\\dev\\alrs_s1.csv', header=None, names=['date', 'time', 'open', 'close', 'high', 'low', 'volume'])

# %%
#print(df2.groupby(['date'])['volume'].count())
#df2.loc[df2['date'=='20180622']]
df2[df2.date==20180622]
#df2.date.count()   # 1517766
# Out:
#              date    time   open  close   high    low   volume
# 1408981  20180622  100001  97.99  97.99  97.65  97.66    18700
# 1408982  20180622  100002  97.79  97.85  97.62  97.62    48100
# 1408983  20180622  100003  97.62  97.64  97.62  97.64      400
# 1408984  20180622  100004  97.64  97.70  97.64  97.64      400
# 1408985  20180622  100005  97.70  97.73  97.64  97.73    11000
# 1408986  20180622  100006  97.73  97.74  97.73  97.74     4600
# 1408987  20180622  100007  97.71  97.71  97.64  97.64      700
# 1408988  20180622  100008  97.79  97.79  97.79  97.79      100
# 1408989  20180622  100011  97.64  97.64  97.64  97.64      200
# 1408990  20180622  100012  97.62  97.62  97.62  97.62     3000
# 1408991  20180622  100014  97.62  97.62  97.62  97.62     1200
# 1408992  20180622  100020  97.76  97.76  97.76  97.76      200
# 1408993  20180622  100021  97.66  97.76  97.64  97.64     5700
# 1408994  20180622  100024  97.70  97.70  97.70  97.70      100
# ...

# %%
df2.loc[['date']=='20111130']
# Out:
# date      20111129.0
# time        100146.0
# open            35.0
# close           35.0
# high            35.0
# low             35.0
# volume         100.0
# Name: 0, dtype: float64

# %%
df_header = pd.DataFrame()
df_header = {'date':[],'time':[],'open':[],'close':[],'high':[],'low':[],'volume':[]}
df_header
# Out:
# {'close': [],
#  'date': [],
#  'high': [],
#  'low': [],
#  'open': [],
#  'time': [],
#  'volume': []}

# %%
df_header = pd.DataFrame(data=df_header)

# %%
df_header.head()
# Out:
# Empty DataFrame
# Columns: [close, date, high, low, open, time, volume]
# Index: []

# %%
df_header = pd.DataFrame(columns=['date', 'time', 'open', 'close', 'high', 'low', 'volume'])

# %%
df_header.head()
# Out:
# Empty DataFrame
# Columns: [date, time, open, close, high, low, volume]
# Index: []

# %%
df22=df_header

# %%
df22
# Out:
# Empty DataFrame
# Columns: [date, time, open, close, high, low, volume]
# Index: []

# %%
df2[:3]
# Out:
#        date    time   open  close   high    low  volume
# 0  20111129  100146  35.00  35.00  35.00  35.00     100
# 1  20111130  100231  48.32  48.32  48.32  48.32     500
# 2  20111206  100221  37.00  37.00  37.00  37.00     100

# %%
df22.append(df2)
df22[:10]
# Out:
# Empty DataFrame
# Columns: [date, time, open, close, high, low, volume]
# Index: []

# %%
df22.head()
# Out:
# Empty DataFrame
# Columns: [date, time, open, close, high, low, volume]
# Index: []
